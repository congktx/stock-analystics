# %%
# !pip install gdown
# !gdown '1lFme1uSV4rOvu6ozjeq9rWdb7ti8fj3E'
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1lFme1uSV4rOvu6ozjeq9rWdb7ti8fj3E
# To: /kaggle/working/tickers.json
# 100%|████████████████████████████████████████| 301k/301k [00:00<00:00, 66.0MB/s]

# %%
import json

import time

# %%
def load_json_file(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

    return {}

# %%
def save_json_file(path, data):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=4, ensure_ascii=False)
        return True
    return False

# %%
list_ticker = load_json_file('/kaggle/working/tickers.json')

part = 1
ln = len(list_ticker)
l = 0 
r = ln
if part != 1:
    l = ln//4 * (part - 1)
if part != 4:
    r = ln//4 * part
list_ticker = list_ticker[l:r]
print(len(list_ticker))
# Out:
# 1252

# %%
import requests
def get_more_company_infos(date: str = "2024-12-01", ticker: str = 'AACG'):
    params = {
        "apiKey": PolygonAPIKey,
        "date": date
    }
    
    headers = {
        "Content-Type": "application/json"
    }
    
    url = f'https://api.massive.com/v3/reference/tickers/{ticker}'
    
    try:
        response = requests.get(url, params=params, headers=headers).json()

        if not response.get('results'):
            return response.get('errors')

        return response['results']
    except Exception as e:
        print(f"Error fetching data: {e}")
        return None

# %%
list_company_infos = []
for ticker in list_ticker:
    print(ticker.get('ticker'))
    list_company_infos.append(get_more_company_infos(ticker.get('date'), ticker.get('ticker')))
    time.sleep(12)
save_json_file('./company_infos.json', json.dumps(list_company_infos, indent=2))
# Out:
# AACG
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_47/1405203073.py in <cell line: 0>()
#       3     print(ticker.get('ticker'))
#       4     list_company_infos.append(get_more_company_infos(ticker.get('date'), ticker.get('ticker')))
# ----> 5     time.sleep(12)
#       6 save_json_file('./company_infos.json', json.dumps(list_company_infos, indent=2))
#
# KeyboardInterrupt:
